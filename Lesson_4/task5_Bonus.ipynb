# %%
             # 1 ответ:   
answers_1 = ["Python – это язык программирования будущего! Машинное обучение и"
                   " искусственный интеллект – это будущее IT-сферы,\nкоторое уже наступает. "
                   "Благодаря библиотекам Python, отвечающим за симуляцию нейронных связей в программировании,\n"
                   "ТОП-компании сейчас занимаются микро и макропроектами, которые уже через несколько лет начнут"
                   " задавать тон в разработке веб-ресурсов.",
                   # 2 ответ:
                   "1. Нам потребуется чистая флешка на 8 Гб или более, загрузчик Clover, ну и сам образ операционной системы (придется поискать самостоятельно).\n"
                   "2. Когда macOS будет развернута на флешку, начнется первый самый сложный процесс. Нужно добиться запуска системы на нашем железе.\n"
                   "Для этого придется постоянно подбрасывать патчи и фиксы в загрузчик.Все необходимое можно найти в одном из самых крупных\n"
                   "хакинтош-сообществ osx86project или на GitHub.",
             # 3 ответ:
             "Выбор видеокарты – важный подготовительный этап. Для майнинга подойдет видеокарта AMD или Nvidia. Для майнинга не подходит аппаратное\n"
             "обеспечение ноутбука. Лучше выбрать топовую видеокарту карту AMD, но подойдут модели от 6XXX серии и выше. NVIDIA RTX 3XXX. Ваш будущий заработок будет зависеть\n"
             "от производительности видеокарты, поэтому на этом этапе не стоит экономить. Операционную систему рекомендуем HiveOS на базе Linux."]
            # 1 ответ:
answers_2 = ["Эксперты авторитетного британского издания назвали 5 самых экономичных автомобилей на рынке по состоянию на первый квартал 2022 года.\n"
             "Peugeot 208: Расход топлива на 100 км – 3.96 л.\n"
             "Opel Corsa: Расход топлива на 100 км – 4 л.\n"
             "Volkswagen Golf: Расход топлива на 100 км – 4.1 л.\n"
             "Renault Clio: Расход топлива на 100 км – 4.2 л.\n"
             "SEAT Leon: Расход топлива на 100 км – 4.2 л.",
             # 2 ответ:
             "Внимание! Торговля криптовалютой связана с высокими риссками и потерей всех збережений.Подходите к этому процессу с умом!\n"
             "В 2022 году возможны три сценария:\n"
             "- До конца первого квартала 2022 года мы увидим резкое увеличение объема рынка, за которым последует такое же резкое падение и неглубокий, но болезненный многолетний медвежий рынок.\n"
             "- Объем денежных средств в криптовалюте вырастет до $20 трлн и будет держаться на этом уровне весь год.\n"
             "- Медленно, но верно объем средств в криптовалюте будет двигаться вверх к бесконечности.",
             # 3 ответ:
             "ТОП 5 стран по рынку жилой недвижимости в странах Европы:\n"
             "1. Великобритания\n"
             "2. Германия\n"
             "3. Грузия\n"
             "4. Ирландия\n"
             "5. Испания"]
while True:
    user_name = input('Мы рады видеть новых пользователей!\nВведите ваше имя: ')
    if user_name == 'q':
        break
    user_age = input(f'Добрый день {user_name.title()}\nСколько вам лет: ')
    if user_age == 'q':
        break
    if int(user_age) < 25:
        questions = input('Привет! Как поживаешь? На какую тему поговорим?\n'
                         '1. Какой язык програмирования выбрать новичку?\n'
                         '2. Как установить macOS на PC?\n'
                         '3. Как начать майнить на GPU?\n'
                         'Для вывода ответа введи номер вопроса: ')
        print()
        if questions == 'q':
            break
        else:
            print('*' * 8, 'ОТВЕТ', '*' * 8, sep=' ')
            print(answers_1[int(questions) - 1])
            print('*' * 23)
            break

    if 25 <= int(user_age) < 100:
        questions = input('Приветствую вас! На какую тему хотите поговорить?\n'
                          '1. Какой экономичный автомобиль выбрать в 2022 году?\n'
                          '2. Стоит ли вкладывать средства в криптовалюту?\n'
                          '3. Где выгоднее покупать недвижимость?\n'
                          'Для вывода ответа введите номер вопроса: ')
        print()
        if questions == 'q':
            break
        else:
            print('*' * 8, 'ОТВЕТ', '*' * 8, sep=' ')
            print(answers_2[int(questions) - 1])
            print('*' * 23)
            break
    else:
        print('Уважаемый долгожитель, могу посоветовать Вам отличную Криокамеру.'
              'Мы надеемся что в будущем сможем Вас оживить и при необходимости - вылечить')
        break
# Out:
# Мы рады видеть новых пользователей!
# Введите ваше имя: дмитрий
# Добрый день Дмитрий
# Сколько вам лет: 30
# Приветствую вас! На какую тему хотите поговорить?
# 1. Какой экономичный автомобиль выбрать в 2022 году?
# 2. Стоит ли вкладывать средства в криптовалюту?
# 3. Где выгоднее покупать недвижимость?
# Для вывода ответа введите номер вопроса: 2
#
# ******** ОТВЕТ ********
# Внимание! Торговля криптовалютой связана с высокими риссками и потерей всех збережений.Подходите к этому процессу с умом!
# В 2022 году возможны три сценария:
# - До конца первого квартала 2022 года мы увидим резкое увеличение объема рынка, за которым последует такое же резкое падение и неглубокий, но болезненный многолетний медвежий рынок.
# - Объем денежных средств в криптовалюте вырастет до $20 трлн и будет держаться на этом уровне весь год.
# - Медленно, но верно объем средств в криптовалюте будет двигаться вверх к бесконечности.
# ***********************
